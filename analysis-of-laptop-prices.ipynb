# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptop_price - dataset.csv')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#   CPU_Company       CPU_Type  CPU_Frequency (GHz)  RAM (GB)  \
# 0       Intel        Core i5                  2.3         8
# 1       Intel        Core i5                  1.8         8
# 2       Intel  Core i5 7200U                  2.5         8
# 3       Intel        Core i7                  2.7        16
# 4       Intel        Core i5                  3.1         8
#
#                 Memory GPU_Company                GPU_Type  OpSys  \
# ...

# %%
df.describe()
# Out:
#             Inches  CPU_Frequency (GHz)     RAM (GB)  Weight (kg)  \
# count  1275.000000          1275.000000  1275.000000  1275.000000
# mean     15.022902             2.302980     8.440784     2.040525
# std       1.429470             0.503846     5.097809     0.669196
# min      10.100000             0.900000     2.000000     0.690000
# 25%      14.000000             2.000000     4.000000     1.500000
# 50%      15.600000             2.500000     8.000000     2.040000
# 75%      15.600000             2.700000     8.000000     2.310000
# max      18.400000             3.600000    64.000000     4.700000
#
#        Price (Euro)
# count   1275.000000
# mean    1134.969059
# std      700.752504
# min      174.000000
# 25%      609.000000
# 50%      989.000000
# 75%     1496.500000
# max     6099.000000

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution',
#        'CPU_Company', 'CPU_Type', 'CPU_Frequency (GHz)', 'RAM (GB)', 'Memory',
#        'GPU_Company', 'GPU_Type', 'OpSys', 'Weight (kg)', 'Price (Euro)'],
#       dtype='object')

# %%
df = df[['Company', 'Product','CPU_Type', 'ScreenResolution','CPU_Frequency (GHz)','RAM (GB)',     
       'Memory','GPU_Type','OpSys', 'Weight (kg)', 'Price (Euro)']].dropna()

# %%
df.head(5)
# Out:
#   Company      Product       CPU_Type                    ScreenResolution  \
# 0   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air        Core i5                            1440x900
# 2      HP       250 G6  Core i5 7200U                   Full HD 1920x1080
# 3   Apple  MacBook Pro        Core i7  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory                GPU_Type  \
# 0                  2.3         8            128GB SSD  Iris Plus Graphics 640
# 1                  1.8         8  128GB Flash Storage        HD Graphics 6000
# 2                  2.5         8            256GB SSD         HD Graphics 620
# 3                  2.7        16            512GB SSD          Radeon Pro 455
# 4                  3.1         8            256GB SSD  Iris Plus Graphics 650
#
#    OpSys  Weight (kg)  Price (Euro)
# ...

# %%
df.describe()
# Out:
#        CPU_Frequency (GHz)     RAM (GB)  Weight (kg)  Price (Euro)
# count          1275.000000  1275.000000  1275.000000   1275.000000
# mean              2.302980     8.440784     2.040525   1134.969059
# std               0.503846     5.097809     0.669196    700.752504
# min               0.900000     2.000000     0.690000    174.000000
# 25%               2.000000     4.000000     1.500000    609.000000
# 50%               2.500000     8.000000     2.040000    989.000000
# 75%               2.700000     8.000000     2.310000   1496.500000
# max               3.600000    64.000000     4.700000   6099.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              1275 non-null   object
#  1   Product              1275 non-null   object
#  2   CPU_Type             1275 non-null   object
#  3   ScreenResolution     1275 non-null   object
#  4   CPU_Frequency (GHz)  1275 non-null   float64
#  5   RAM (GB)             1275 non-null   int64
#  6   Memory               1275 non-null   object
#  7   GPU_Type             1275 non-null   object
#  8   OpSys                1275 non-null   object
#  9   Weight (kg)          1275 non-null   float64
#  10  Price (Euro)         1275 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 109.7+ KB

# %%
df.to_csv("C:\\Users\\JOHN\\Desktop\\laptop_price - dataset_cleaned.csv",index=False)

# %%
df.head()
# Out:
#   Company      Product       CPU_Type                    ScreenResolution  \
# 0   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air        Core i5                            1440x900
# 2      HP       250 G6  Core i5 7200U                   Full HD 1920x1080
# 3   Apple  MacBook Pro        Core i7  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory                GPU_Type  \
# 0                  2.3         8            128GB SSD  Iris Plus Graphics 640
# 1                  1.8         8  128GB Flash Storage        HD Graphics 6000
# 2                  2.5         8            256GB SSD         HD Graphics 620
# 3                  2.7        16            512GB SSD          Radeon Pro 455
# 4                  3.1         8            256GB SSD  Iris Plus Graphics 650
#
#    OpSys  Weight (kg)  Price (Euro)
# ...

# %%
df.isna().sum()
# Out:
# Company                0
# Product                0
# CPU_Type               0
# ScreenResolution       0
# CPU_Frequency (GHz)    0
# RAM (GB)               0
# Memory                 0
# GPU_Type               0
# OpSys                  0
# Weight (kg)            0
# Price (Euro)           0
# dtype: int64

# %%
df.head(5)
# Out:
#   Company      Product       CPU_Type                    ScreenResolution  \
# 0   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air        Core i5                            1440x900
# 2      HP       250 G6  Core i5 7200U                   Full HD 1920x1080
# 3   Apple  MacBook Pro        Core i7  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory                GPU_Type  \
# 0                  2.3         8            128GB SSD  Iris Plus Graphics 640
# 1                  1.8         8  128GB Flash Storage        HD Graphics 6000
# 2                  2.5         8            256GB SSD         HD Graphics 620
# 3                  2.7        16            512GB SSD          Radeon Pro 455
# 4                  3.1         8            256GB SSD  Iris Plus Graphics 650
#
#    OpSys  Weight (kg)  Price (Euro)
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'CPU_Type', 'ScreenResolution',
#        'CPU_Frequency (GHz)', 'RAM (GB)', 'Memory', 'GPU_Type', 'OpSys',
#        'Weight (kg)', 'Price (Euro)'],
#       dtype='object')

# %%
df.duplicated(subset=['Company', 'Product', 'CPU_Type','ScreenResolution', 'CPU_Frequency (GHz)', 'RAM (GB)',
       'Memory', 'GPU_Type', 'OpSys', 'Weight (kg)', 'Price (Euro)']).sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#   Company      Product       CPU_Type                    ScreenResolution  \
# 0   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air        Core i5                            1440x900
# 2      HP       250 G6  Core i5 7200U                   Full HD 1920x1080
# 3   Apple  MacBook Pro        Core i7  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory                GPU_Type  \
# 0                  2.3         8            128GB SSD  Iris Plus Graphics 640
# 1                  1.8         8  128GB Flash Storage        HD Graphics 6000
# 2                  2.5         8            256GB SSD         HD Graphics 620
# 3                  2.7        16            512GB SSD          Radeon Pro 455
# 4                  3.1         8            256GB SSD  Iris Plus Graphics 650
#
#    OpSys  Weight (kg)  Price (Euro)
# ...

# %%
df[['Company', 'Product', 'CPU_Type','ScreenResolution', 'CPU_Frequency (GHz)', 'RAM (GB)',
       'Memory', 'GPU_Type', 'OpSys', 'Weight (kg)', 'Price (Euro)']].dropna()
# Out:
#      Company                              Product                 CPU_Type  \
# 0      Apple                          MacBook Pro                  Core i5
# 1      Apple                          Macbook Air                  Core i5
# 2         HP                               250 G6            Core i5 7200U
# 3      Apple                          MacBook Pro                  Core i7
# 4      Apple                          MacBook Pro                  Core i5
# ...      ...                                  ...                      ...
# 1270  Lenovo                       Yoga 500-14ISK            Core i7 6500U
# 1271  Lenovo                       Yoga 900-13ISK            Core i7 6500U
# 1272  Lenovo                   IdeaPad 100S-14IBR  Celeron Dual Core N3050
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Core i7 6500U
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)  Celeron Dual Core N3050
#
# ...

# %%
df2 = df.drop(['Company', 'Product', 'CPU_Type','ScreenResolution','Memory', 'GPU_Type', 'OpSys'], axis =1)

# %%
df2.corr()
# Out:
#                      CPU_Frequency (GHz)  RAM (GB)  Weight (kg)  Price (Euro)
# CPU_Frequency (GHz)             1.000000  0.366254     0.318649      0.428847
# RAM (GB)                        0.366254  1.000000     0.389370      0.740287
# Weight (kg)                     0.318649  0.389370     1.000000      0.211883
# Price (Euro)                    0.428847  0.740287     0.211883      1.000000

# %%
sns.heatmap(df2.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.head(2)
# Out:
#   Company      Product CPU_Type                    ScreenResolution  \
# 0   Apple  MacBook Pro  Core i5  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Core i5                            1440x900
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory                GPU_Type  \
# 0                  2.3         8            128GB SSD  Iris Plus Graphics 640
# 1                  1.8         8  128GB Flash Storage        HD Graphics 6000
#
#    OpSys  Weight (kg)  Price (Euro)
# 0  macOS         1.37       1339.69
# 1  macOS         1.34        898.94

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
ax = df['Company'].value_counts().plot(kind='barh')
ax.set_xlabel('Product Count')
ax.set_ylabel('Company')

plt.rcParams['figure.figsize']=(20,7)

# %%
ax = df['Company'].value_counts().head(10).plot(kind='barh',title='Top 10 performing Laptop company')
ax.set_xlabel('Product Count')
ax.set_ylabel('Company')
# Out:
# Text(0, 0.5, 'Company')

# %%
df[df['Company'].str.contains('Huawei')]
# Out:
#     Company     Product       CPU_Type             ScreenResolution  \
# 170  Huawei  MateBook X  Core i5 7200U  IPS Panel Full HD 2160x1440
# 214  Huawei  MateBook X  Core i7 7500U  IPS Panel Full HD 2160x1440
#
#      CPU_Frequency (GHz)  RAM (GB)     Memory         GPU_Type       OpSys  \
# 170                  2.5         8  256GB SSD  HD Graphics 620  Windows 10
# 214                  2.7         8  512GB SSD  HD Graphics 620  Windows 10
#
#      Weight (kg)  Price (Euro)
# 170         1.05        1349.0
# 214         1.05        1499.0

# %%
df[df['Company'].str.contains('LG')]
# Out:
#     Company      Product       CPU_Type  \
# 678      LG  Gram 15Z975  Core i7 8550U
# 905      LG  Gram 15Z970  Core i7 7500U
# 909      LG  Gram 14Z970  Core i7 7500U
#
#                               ScreenResolution  CPU_Frequency (GHz)  RAM (GB)  \
# 678                IPS Panel Full HD 1920x1080                  1.8         8
# 905  IPS Panel Full HD / Touchscreen 1920x1080                  2.7        16
# 909  IPS Panel Full HD / Touchscreen 1920x1080                  2.7         8
#
#         Memory         GPU_Type       OpSys  Weight (kg)  Price (Euro)
# 678  512GB SSD  HD Graphics 620  Windows 10         1.09        2299.0
# 905  512GB SSD  HD Graphics 620  Windows 10         1.08        2099.0
# 909  512GB SSD  HD Graphics 620  Windows 10         0.98        1899.0

# %%
df[df['Company'].str.contains('Acer')]
# Out:
#      Company                               Product                 CPU_Type  \
# 5       Acer                              Aspire 3           A9-Series 9420
# 9       Acer                               Swift 3            Core i5 8250U
# 36      Acer                              Aspire 3            Core i3 7130U
# 43      Acer                       Aspire A515-51G            Core i5 8250U
# 51      Acer                       Aspire A515-51G            Core i7 8550U
# ...      ...                                   ...                      ...
# 1215    Acer      C740-C9QX (3205U/2GB/32GB/Chrome  Celeron Dual Core 3205U
# 1216    Acer                               E5 774G            Core i3 6006U
# 1219    Acer  SP714-51 (i7-7Y75/8GB/256GB/FHD/W10)             Core i7 7Y75
# 1242    Acer                        Aspire ES1-572            Core i3 6006U
# 1263    Acer                        Aspire ES1-531  Celeron Dual Core N3060
#
# ...

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Vostro 3568                            19
# Legion Y520-15IKBN                     19
#                                        ..
# VivoBook E201NA                         1
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: count, Length: 618, dtype: int64

# %%
df['Product'].value_counts().head(10)
# Out:
# Product
# XPS 13                30
# Inspiron 3567         25
# 250 G6                21
# Vostro 3568           19
# Legion Y520-15IKBN    19
# ProBook 450           18
# Inspiron 5570         18
# Alienware 17          15
# Inspiron 5567         14
# Satellite Pro         13
# Name: count, dtype: int64

# %%
ax = df['Product'].value_counts().head(10).plot(kind='bar', title='Top 10 Laptop products sales')
ax.set_xlabel('Laptop product')
ax.set_ylabel('Sale counts')
# Out:
# Text(0, 0.5, 'Sale counts')

# %%
df[df['Product'].str.contains('XPS 13')]
# Out:
#      Company Product       CPU_Type  \
# 19      Dell  XPS 13  Core i5 8250U
# 33      Dell  XPS 13  Core i7 8550U
# 89      Dell  XPS 13  Core i7 8550U
# 111     Dell  XPS 13  Core i7 7560U
# 114     Dell  XPS 13  Core i5 8250U
# 181     Dell  XPS 13  Core i5 8250U
# 207     Dell  XPS 13  Core i7 8550U
# 208     Dell  XPS 13  Core i7 8550U
# 311     Dell  XPS 13  Core i7 8550U
# 344     Dell  XPS 13  Core i7 8550U
# 510     Dell  XPS 13  Core i5 7200U
# 540     Dell  XPS 13  Core i7 8550U
# 565     Dell  XPS 13  Core i5 8250U
# 636     Dell  XPS 13  Core i5 8250U
# 652     Dell  XPS 13  Core i5 8250U
# 802     Dell  XPS 13  Core i5 7200U
# 864     Dell  XPS 13  Core i7 7660U
# 900     Dell  XPS 13   Core i7 7Y75
# 902     Dell  XPS 13   Core i7 7Y75
# 956     Dell  XPS 13   Core i5 7Y54
# 958     Dell  XPS 13  Core i7 6500U
# 970     Dell  XPS 13   Core i7 7Y75
# 1028    Dell  XPS 13  Core i5 7200U
# 1054    Dell  XPS 13  Core i7 7500U
# 1065    Dell  XPS 13  Core i7 7500U
# ...

# %%
df[df['Product'].str.contains('Inspiron 3567')]
# Out:
#      Company        Product       CPU_Type      ScreenResolution  \
# 13      Dell  Inspiron 3567  Core i3 6006U     Full HD 1920x1080
# 16      Dell  Inspiron 3567  Core i7 7500U     Full HD 1920x1080
# 25      Dell  Inspiron 3567  Core i3 6006U              1366x768
# 48      Dell  Inspiron 3567  Core i5 7200U     Full HD 1920x1080
# 96      Dell  Inspiron 3567  Core i7 7500U     Full HD 1920x1080
# 97      Dell  Inspiron 3567  Core i3 6006U     Full HD 1920x1080
# 131     Dell  Inspiron 3567  Core i3 6006U     Full HD 1920x1080
# 175     Dell  Inspiron 3567  Core i3 7100U              1366x768
# 206     Dell  Inspiron 3567  Core i3 7100U  Touchscreen 1366x768
# 264     Dell  Inspiron 3567  Core i5 7200U     Full HD 1920x1080
# 281     Dell  Inspiron 3567  Core i3 6006U     Full HD 1920x1080
# 358     Dell  Inspiron 3567  Core i5 7200U  Touchscreen 1366x768
# 415     Dell  Inspiron 3567  Core i5 7200U     Full HD 1920x1080
# ...

# %%
df[df['Product'].str.contains('250 G6')]
# Out:
#      Company Product                 CPU_Type   ScreenResolution  \
# 2         HP  250 G6            Core i5 7200U  Full HD 1920x1080
# 10        HP  250 G6            Core i5 7200U           1366x768
# 11        HP  250 G6            Core i3 6006U  Full HD 1920x1080
# 38        HP  250 G6            Core i5 7200U           1366x768
# 64        HP  250 G6            Core i5 7200U  Full HD 1920x1080
# 66        HP  250 G6            Core i3 6006U           1366x768
# 87        HP  250 G6            Core i5 7200U  Full HD 1920x1080
# 125       HP  250 G6  Celeron Dual Core N3060           1366x768
# 309       HP  250 G6            Core i3 6006U  Full HD 1920x1080
# 360       HP  250 G6            Core i3 6006U           1366x768
# 363       HP  250 G6            Core i5 7200U  Full HD 1920x1080
# 537       HP  250 G6  Pentium Quad Core N3710  Full HD 1920x1080
# 548       HP  250 G6            Core i3 6006U  Full HD 1920x1080
# ...

# %%
df[df['Product'].str.contains('Vostro 3568')]
# Out:
#      Company      Product       CPU_Type   ScreenResolution  \
# 263     Dell  Vostro 3568  Core i5 7200U  Full HD 1920x1080
# 481     Dell  Vostro 3568  Core i3 7100U           1366x768
# 559     Dell  Vostro 3568  Core i3 6006U           1366x768
# 604     Dell  Vostro 3568  Core i3 6006U           1366x768
# 612     Dell  Vostro 3568  Core i3 6006U           1366x768
# 616     Dell  Vostro 3568  Core i5 7200U  Full HD 1920x1080
# 741     Dell  Vostro 3568  Core i3 6006U           1366x768
# 814     Dell  Vostro 3568  Core i5 7200U  Full HD 1920x1080
# 843     Dell  Vostro 3568  Core i5 7200U           1366x768
# 845     Dell  Vostro 3568  Core i7 7500U  Full HD 1920x1080
# 886     Dell  Vostro 3568  Core i3 6006U           1366x768
# 898     Dell  Vostro 3568  Core i3 6006U           1366x768
# 920     Dell  Vostro 3568  Core i5 7200U           1366x768
# 928     Dell  Vostro 3568  Core i5 7200U           1366x768
# 936     Dell  Vostro 3568  Core i3 6006U           1366x768
# ...

# %%
df[df['Product'].str.contains('Legion Y520-15IKBN')]
# Out:
#      Company             Product        CPU_Type             ScreenResolution  \
# 21    Lenovo  Legion Y520-15IKBN  Core i5 7300HQ  IPS Panel Full HD 1920x1080
# 142   Lenovo  Legion Y520-15IKBN  Core i7 7700HQ  IPS Panel Full HD 1920x1080
# 163   Lenovo  Legion Y520-15IKBN  Core i7 7700HQ  IPS Panel Full HD 1920x1080
# 187   Lenovo  Legion Y520-15IKBN  Core i5 7300HQ  IPS Panel Full HD 1920x1080
# 205   Lenovo  Legion Y520-15IKBN  Core i7 7700HQ            Full HD 1920x1080
# 282   Lenovo  Legion Y520-15IKBN  Core i5 7300HQ  IPS Panel Full HD 1920x1080
# 288   Lenovo  Legion Y520-15IKBN  Core i7 7700HQ  IPS Panel Full HD 1920x1080
# 345   Lenovo  Legion Y520-15IKBN  Core i7 7700HQ  IPS Panel Full HD 1920x1080
# 367   Lenovo  Legion Y520-15IKBN  Core i5 7300HQ  IPS Panel Full HD 1920x1080
# 509   Lenovo  Legion Y520-15IKBN  Core i7 7700HQ  IPS Panel Full HD 1920x1080
# 640   Lenovo  Legion Y520-15IKBN  Core i7 7700HQ  IPS Panel Full HD 1920x1080
# ...

# %%
df['CPU_Type'].value_counts().head(10)
# Out:
# CPU_Type
# Core i5 7200U     193
# Core i7 7700HQ    147
# Core i7 7500U     133
# Core i3 6006U      81
# Core i7 8550U      73
# Core i5 8250U      72
# Core i5 6200U      68
# Core i7 6500U      43
# Core i7 6700HQ     41
# Core i3 7100U      35
# Name: count, dtype: int64

# %%
ax = df['CPU_Type'].value_counts().head(10).plot(kind='barh', title='Top 10 purchase count by CPU_Type')
ax.set_xlabel('Count')
ax.set_ylabel('CPU_Type')
# Out:
# Text(0, 0.5, 'CPU_Type')

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                505
# 1366x768                                         263
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['ScreenResolution'].value_counts().plot(kind='barh')

plt.rcParams['figure.figsize']=(20,7)

# %%
ax = df['ScreenResolution'].value_counts().head(10).plot(kind='barh',title='Laptop purchase count by screenResolution')
ax.set_xlabel('Count')
ax.set_ylabel('ScreenResolution')
# Out:
# Text(0, 0.5, 'ScreenResolution')

# %%
df['CPU_Frequency (GHz)'].value_counts()
# Out:
# CPU_Frequency (GHz)
# 2.50    285
# 2.80    165
# 2.70    164
# 1.60    124
# 2.30     86
# 2.00     86
# 1.80     78
# 2.60     74
# 1.10     53
# 2.40     49
# 2.90     19
# 3.00     19
# 1.20     15
# 1.44     12
# 2.20     11
# 1.50     10
# 1.30      6
# 3.60      5
# 3.10      3
# 2.10      3
# 1.90      2
# 0.90      2
# 3.20      1
# 1.00      1
# 1.92      1
# Name: count, dtype: int64

# %%
ax = df['CPU_Frequency (GHz)'].value_counts().head(12).plot(kind='barh', title='Laptop purchase count by CPU_Frequency (GHz)')
ax.set_xlabel('Laptop purchase count')
ax.set_ylabel('CPU_Frequency (GHz)')
# Out:
# Text(0, 0.5, 'CPU_Frequency (GHz)')

# %%
df['RAM (GB)'].value_counts()
# Out:
# RAM (GB)
# 8     613
# 4     367
# 16    198
# 6      35
# 12     25
# 32     17
# 2      16
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
ax = df['RAM (GB)'].value_counts().plot(kind='barh',title='RAM (GB) by count of Laptop purchase')
ax.set_xlabel('Count')
ax.set_ylabel('RAM (GB)')
# Out:
# Text(0, 0.5, 'RAM (GB)')

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        411
# 1TB HDD                          215
# 500GB HDD                        124
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'].value_counts().head(11).plot(kind='barh',title='Memory by count of Laptop purchase')
ax.set_xlabel('Count')
ax.set_ylabel('Memory')
# Out:
# Text(24.140625000000014, 0.5, 'Memory')

# %%
df.head(2)
# Out:
#   Company      Product CPU_Type                    ScreenResolution  \
# 0   Apple  MacBook Pro  Core i5  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Core i5                            1440x900
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory                GPU_Type  \
# 0                  2.3         8            128GB SSD  Iris Plus Graphics 640
# 1                  1.8         8  128GB Flash Storage        HD Graphics 6000
#
#    OpSys  Weight (kg)  Price (Euro)
# 0  macOS         1.37       1339.69
# 1  macOS         1.34        898.94

# %%
df['GPU_Type'].value_counts().head(10)
# Out:
# GPU_Type
# HD Graphics 620     280
# HD Graphics 520     181
# UHD Graphics 620     68
# GeForce GTX 1050     66
# GeForce GTX 1060     48
# GeForce 940MX        43
# Radeon 530           41
# HD Graphics 500      39
# HD Graphics 400      33
# GeForce GTX 1070     30
# Name: count, dtype: int64

# %%
df['GPU_Type'].value_counts().head(10).plot(kind='barh',title='GPU_Type by count of Laptop purchase')
ax.set_xlabel('Count')
ax.set_ylabel('GPU_Type')
# Out:
# Text(24.140625000000014, 0.5, 'GPU_Type')

# %%
df['Weight (kg)'].value_counts().head(10)
# Out:
# Weight (kg)
# 2.20    120
# 2.10     58
# 2.00     45
# 2.40     42
# 2.50     38
# 2.30     37
# 2.80     28
# 1.86     25
# 1.40     24
# 1.20     24
# Name: count, dtype: int64

# %%
df['Weight (kg)'].value_counts().head(10).plot(kind='barh',title='Weight (kg) by count of Laptop purchase')
ax.set_xlabel('Count')
ax.set_ylabel('Weight (kg)')
# Out:
# Text(24.140625000000014, 0.5, 'Weight (kg)')

# %%
df['Price (Euro)'].value_counts().head(10)
# Out:
# Price (Euro)
# 1099.0    14
# 1799.0    14
# 1499.0    12
# 1199.0    11
# 1299.0    11
# 499.0     11
# 999.0     10
# 1349.0     9
# 1399.0     9
# 899.0      9
# Name: count, dtype: int64

# %%
ax = df['Price (Euro)'].value_counts().head(10).plot(kind='barh',title='Top 10 Laptop purchases by Price (Euro) ')
ax.set_xlabel('Count of Laptop purchase')
ax.set_ylabel('Price (Euro)')
# Out:
# Text(0, 0.5, 'Price (Euro)')

# %%
ax = df['Price (Euro)'].plot(kind='hist', title='Laptop Price (Euro)')

ax.set_xlabel('Price (Euro)')
# Out:
# Text(0.5, 0, 'Price (Euro)')

# %%
ax = df['Price (Euro)'].plot(kind='kde', title='Laptop Price (Euro)')

ax.set_xlabel('Price (Euro)')
# Out:
# Text(0.5, 0, 'Price (Euro)')

# %%
sns.barplot(x = df['Company'], y = df['Price (Euro)'])
plt.rcParams['figure.figsize']=(40,10)

# %%
sns.barplot(x = df['RAM (GB)'],y = df['Price (Euro)'])
# Out:
# <Axes: xlabel='RAM (GB)', ylabel='Price (Euro)'>

# %%
sns.barplot(x = df['GPU_Type'].head(10),y = df['Price (Euro)'])
plt.rcParams['figure.figsize']=(20,7)
# Out:
# <Axes: xlabel='GPU_Type', ylabel='Price (Euro)'>

# %%
sns.barplot(x = df['OpSys'].head(10),y = df['Price (Euro)'])
# Out:
# <Axes: xlabel='OpSys', ylabel='Price (Euro)'>

# %%
sns.barplot(x = df['Weight (kg)'].head(10),y = df['Price (Euro)'])
# Out:
# <Axes: xlabel='Weight (kg)', ylabel='Price (Euro)'>

# %%
sns.barplot(x = df['CPU_Type'].head(10),y = df['Price (Euro)'])
# Out:
# <Axes: xlabel='CPU_Type', ylabel='Price (Euro)'>

# %%
df.head(2)
# Out:
#   Company      Product CPU_Type  CPU_Frequency (GHz)  RAM (GB)  \
# 0   Apple  MacBook Pro  Core i5                  2.3         8
# 1   Apple  Macbook Air  Core i5                  1.8         8
#
#                 Memory                GPU_Type  OpSys  Weight (kg)  \
# 0            128GB SSD  Iris Plus Graphics 640  macOS         1.37
# 1  128GB Flash Storage        HD Graphics 6000  macOS         1.34
#
#    Price (Euro)
# 0       1339.69
# 1        898.94

# %%
df.plot(kind='scatter', x='Price (Euro)',y='CPU_Frequency (GHz)', title='Laptop price(Euro) vs CPU_Frequency')

plt.show()
plt.rcParams['figure.figsize']=(20,7)

# %%
ax = df['Price (Euro)'].value_counts().head(20).plot(kind='bar', title = 'Lap_top Prices')
ax.set_xlabel('Price (Euro)')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df.head(5)
# Out:
#   Company      Product       CPU_Type                    ScreenResolution  \
# 0   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air        Core i5                            1440x900
# 2      HP       250 G6  Core i5 7200U                   Full HD 1920x1080
# 3   Apple  MacBook Pro        Core i7  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro        Core i5  IPS Panel Retina Display 2560x1600
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory                GPU_Type  \
# 0                  2.3         8            128GB SSD  Iris Plus Graphics 640
# 1                  1.8         8  128GB Flash Storage        HD Graphics 6000
# 2                  2.5         8            256GB SSD         HD Graphics 620
# 3                  2.7        16            512GB SSD          Radeon Pro 455
# 4                  3.1         8            256GB SSD  Iris Plus Graphics 650
#
#    OpSys  Weight (kg)  Price (Euro)
# ...

# %%
sns.scatterplot(x='Memory',y='Price (Euro)',hue='RAM (GB)', data=df.head(20))
# Out:
# <Axes: xlabel='Memory', ylabel='Price (Euro)'>

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'CPU_Type', 'CPU_Frequency (GHz)', 'RAM (GB)',
#        'Memory', 'GPU_Type', 'OpSys', 'Weight (kg)', 'Price (Euro)'],
#       dtype='object')

# %%
df['Product'].count()
# Out:
# 1274

# %%
df.sort_values(by="Price (Euro)", ascending=False).head(5)
# Out:
#      Company       Product          CPU_Type  \
# 196    Razer     Blade Pro    Core i7 7820HK
# 830    Razer     Blade Pro    Core i7 7820HK
# 610   Lenovo  Thinkpad P51  Xeon E3-1535M v6
# 749       HP      Zbook 17  Xeon E3-1535M v5
# 1066    Asus    ROG G701VO    Core i7 6820HK
#
#                          ScreenResolution  CPU_Frequency (GHz)  RAM (GB)  \
# 196   4K Ultra HD / Touchscreen 3840x2160                  2.9        32
# 830   4K Ultra HD / Touchscreen 3840x2160                  2.9        32
# 610       IPS Panel 4K Ultra HD 3840x2160                  3.1        32
# 749           IPS Panel Full HD 1920x1080                  2.9        16
# 1066          IPS Panel Full HD 1920x1080                  2.7        64
#
#          Memory          GPU_Type       OpSys  Weight (kg)  Price (Euro)
# 196     1TB SSD  GeForce GTX 1080  Windows 10         3.49        6099.0
# 830   512GB SSD  GeForce GTX 1080  Windows 10         3.49        5499.0
# ...

# %%
df.sort_values(by="Price (Euro)", ascending=True).head()
# Out:
#      Company                               Product                 CPU_Type  \
# 1215    Acer      C740-C9QX (3205U/2GB/32GB/Chrome  Celeron Dual Core 3205U
# 20      Asus                       Vivobook E200HA            Atom x5-Z8350
# 1120    Vero      V131 (X5-Z8350/4GB/32GB/FHD/W10)            Atom X5-Z8350
# 31      Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)         E-Series E2-6110
# 290     Acer                  Chromebook C910-C2ST  Celeron Dual Core 3205U
#
#        ScreenResolution  CPU_Frequency (GHz)  RAM (GB)              Memory  \
# 1215           1366x768                 1.50         2            32GB SSD
# 20             1366x768                 1.44         2  32GB Flash Storage
# 1120  Full HD 1920x1080                 1.44         4  32GB Flash Storage
# 31             1366x768                 1.50         2  32GB Flash Storage
# 290            1366x768                 1.50         2            16GB SSD
#
# ...
